# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv('train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
#  16  HasCoSigner     255347 non-null  object
#  17  Default         255347 non-null  int64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 35.1+ MB

# %%
df.head()
# separe numerical and categorical variables
df_num = df.select_dtypes(include = 'number')
df_cat = df.select_dtypes(include = 'object')
df_cat = df_cat.drop(['LoanID'], axis = 1)
df_cat.head()

# check unique values of categorical variables before encoding
for column in df_cat.columns:
    print(column)
    print(df_cat[column].unique())

df_cat_hot = df_cat[['HasMortgage','HasDependents','HasCoSigner']]
df_cat_label = df_cat.drop(df_cat_hot.columns, axis = 1)
df_cat_label
# Out:
# Education
# ["Bachelor's" "Master's" 'High School' 'PhD']
# EmploymentType
# ['Full-time' 'Unemployed' 'Self-employed' 'Part-time']
# MaritalStatus
# ['Divorced' 'Married' 'Single']
# HasMortgage
# ['Yes' 'No']
# HasDependents
# ['Yes' 'No']
# LoanPurpose
# ['Other' 'Auto' 'Business' 'Home' 'Education']
# HasCoSigner
# ['Yes' 'No']
#           Education EmploymentType MaritalStatus LoanPurpose
# 0        Bachelor's      Full-time      Divorced       Other
# 1          Master's      Full-time       Married       Other
# 2          Master's     Unemployed      Divorced        Auto
# 3       High School      Full-time       Married    Business
# 4        Bachelor's     Unemployed      Divorced        Auto
# ...             ...            ...           ...         ...
# 255342   Bachelor's      Full-time       Married       Other
# 255343  High School      Part-time      Divorced        Home
# 255344  High School  Self-employed       Married        Auto
# 255345  High School      Part-time        Single       Other
# 255346   Bachelor's     Unemployed      Divorced   Education
#
# [255347 rows x 4 columns]

# %% [markdown]
# ### Label encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for column in df_cat_label.columns:
    df_cat_label[f'{column}_encoded'] = le.fit_transform(df_cat_label[column])
    df_cat_label = df_cat_label.drop([column], axis = 1)

df_cat_label.head()
# Out:
#    Education_encoded  EmploymentType_encoded  MaritalStatus_encoded  \
# 0                  0                       0                      0
# 1                  2                       0                      1
# 2                  2                       3                      0
# 3                  1                       0                      1
# 4                  0                       3                      0
#
#    LoanPurpose_encoded
# 0                    4
# 1                    4
# 2                    0
# 3                    1
# 4                    0

# %% [markdown]
# #### One-Hot Encoding

# %%
df_cat_hot = pd.get_dummies(df_cat_hot, columns = df_cat_hot.columns, drop_first = True)
df_cat_hot.head()

df_cat = pd.concat([df_cat_label,df_cat_hot], axis = 1)
df_cat.head()

df_final = pd.concat([df_cat,df_num], axis = 1)
df_final.head()
# Out:
#    Education_encoded  EmploymentType_encoded  MaritalStatus_encoded  \
# 0                  0                       0                      0
# 1                  2                       0                      1
# 2                  2                       3                      0
# 3                  1                       0                      1
# 4                  0                       3                      0
#
#    LoanPurpose_encoded  HasMortgage_Yes  HasDependents_Yes  HasCoSigner_Yes  \
# 0                    4             True               True             True
# 1                    4            False              False             True
# 2                    0             True               True            False
# 3                    1            False              False            False
# 4                    0            False               True            False
#
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Default
# 0         15.23        36      0.44        0
# 1          4.81        60      0.68        0
# 2         21.17        24      0.31        1
# 3          7.07        24      0.23        0
# 4          6.51        48      0.73        0

# %%
X = df_final.drop('Default', axis = 1)
y = df_final['Default']

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif

selector = SelectKBest(score_func = mutual_info_classif, k = 'all')
X_new_all = selector.fit_transform(X,y)

# %%
mask = selector.get_support()

# %%
selected_columns = X.columns[mask]

# %%
print("Selected columns")
print(selected_columns)
# Out:
# Selected columns
# Index(['Education_encoded', 'EmploymentType_encoded', 'MaritalStatus_encoded',
#        'LoanPurpose_encoded', 'HasMortgage_Yes', 'HasDependents_Yes',
#        'HasCoSigner_Yes', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio'],
#       dtype='object')

# %%
X_selected_df = pd.DataFrame(X_new_all, columns = selected_columns)

# %%
'''
# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_selected_df)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build TensorFlow model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Binary classification

# Compile model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

# Train model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate model
loss, accuracy, auc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {accuracy:.4f}, AUC: {auc:.4f}")


import pickle

with open('tensor_all','wb') as f :
    pickle.dump(history, f)
    
'''
# Out:
# Epoch 1/20
# \\?\C:\Users\soonn\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.8773 - auc: 0.7140 - loss: 0.3351 - val_accuracy: 0.8872 - val_auc: 0.7429 - val_loss: 0.3136
# Epoch 2/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 984us/step - accuracy: 0.8857 - auc: 0.7495 - loss: 0.3140 - val_accuracy: 0.8876 - val_auc: 0.7479 - val_loss: 0.3127
# Epoch 3/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 978us/step - accuracy: 0.8849 - auc: 0.7523 - loss: 0.3158 - val_accuracy: 0.8876 - val_auc: 0.7482 - val_loss: 0.3138
# Epoch 4/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 965us/step - accuracy: 0.8855 - auc: 0.7532 - loss: 0.3137 - val_accuracy: 0.8882 - val_auc: 0.7480 - val_loss: 0.3119
# Epoch 5/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 964us/step - accuracy: 0.8850 - auc: 0.7514 - loss: 0.3161 - val_accuracy: 0.8879 - val_auc: 0.7479 - val_loss: 0.3116
# Epoch 6/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 965us/step - accuracy: 0.8848 - auc: 0.7555 - loss: 0.3146 - val_accuracy: 0.8881 - val_auc: 0.7487 - val_loss: 0.3111
# Epoch 7/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 964us/step - accuracy: 0.8864 - auc: 0.7531 - loss: 0.3128 - val_accuracy: 0.8882 - val_auc: 0.7491 - val_loss: 0.3112
# Epoch 8/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 989us/step - accuracy: 0.8842 - auc: 0.7552 - loss: 0.3164 - val_accuracy: 0.8875 - val_auc: 0.7485 - val_loss: 0.3115
# Epoch 9/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 971us/step - accuracy: 0.8859 - auc: 0.7588 - loss: 0.3131 - val_accuracy: 0.8875 - val_auc: 0.7465 - val_loss: 0.3131
# Epoch 10/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 970us/step - accuracy: 0.8866 - auc: 0.7584 - loss: 0.3119 - val_accuracy: 0.8879 - val_auc: 0.7466 - val_loss: 0.3120
# Epoch 11/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 968us/step - accuracy: 0.8866 - auc: 0.7579 - loss: 0.3113 - val_accuracy: 0.8875 - val_auc: 0.7482 - val_loss: 0.3115
# Epoch 12/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 970us/step - accuracy: 0.8855 - auc: 0.7575 - loss: 0.3136 - val_accuracy: 0.8881 - val_auc: 0.7466 - val_loss: 0.3118
# Epoch 13/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 965us/step - accuracy: 0.8860 - auc: 0.7615 - loss: 0.3117 - val_accuracy: 0.8877 - val_auc: 0.7478 - val_loss: 0.3134
# Epoch 14/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 974us/step - accuracy: 0.8869 - auc: 0.7587 - loss: 0.3105 - val_accuracy: 0.8876 - val_auc: 0.7473 - val_loss: 0.3121
# Epoch 15/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 974us/step - accuracy: 0.8867 - auc: 0.7643 - loss: 0.3103 - val_accuracy: 0.8876 - val_auc: 0.7468 - val_loss: 0.3123
# Epoch 16/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 971us/step - accuracy: 0.8870 - auc: 0.7678 - loss: 0.3073 - val_accuracy: 0.8877 - val_auc: 0.7460 - val_loss: 0.3122
# Epoch 17/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 998us/step - accuracy: 0.8874 - auc: 0.7653 - loss: 0.3076 - val_accuracy: 0.8871 - val_auc: 0.7459 - val_loss: 0.3124
# Epoch 18/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 973us/step - accuracy: 0.8865 - auc: 0.7623 - loss: 0.3113 - val_accuracy: 0.8872 - val_auc: 0.7452 - val_loss: 0.3130
# Epoch 19/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 976us/step - accuracy: 0.8855 - auc: 0.7645 - loss: 0.3115 - val_accuracy: 0.8873 - val_auc: 0.7450 - val_loss: 0.3135
# Epoch 20/20
# 5107/5107 ━━━━━━━━━━━━━━━━━━━━ 5s 982us/step - accuracy: 0.8861 - auc: 0.7654 - loss: 0.3105 - val_accuracy: 0.8870 - val_auc: 0.7434 - val_loss: 0.3139
# Test Accuracy: 0.8864, AUC: 0.7485

# %%
with open('tensor_all', 'rb') as f:
    tensor_all = pickle.load(f)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(tensor_all.history['accuracy'], label='Train Acc')
plt.plot(tensor_all.history['val_accuracy'], label='Val Acc')
plt.title('Tensor Flow Model Accuracy with all variables')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# AUC
plt.subplot(1, 2, 2)
plt.plot(tensor_all.history['auc'], label='Train AUC')
plt.plot(tensor_all.history['val_auc'], label='Val AUC')
plt.title('Tensor Flow Model AUC with all variables')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()

plt.tight_layout()
plt.show()
